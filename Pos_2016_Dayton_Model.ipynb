# %%
import matplotlib.pyplot as plt
import pandas as pd
import os
from sklearn.metrics import confusion_matrix
import numpy as np
from sklearn.linear_model import LinearRegression
model = LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
df16 = pd.read_csv(os.path.join('2016_Data'))
del df16['Unnamed: 0']
del df16['Year']
del df16['Month']
del df16['Day']
del df16['Day_of_Week']
del df16['Weekend']
del df16['Datetime']

df16.head()
# Out:
#         MW Utility  Temp(f)
# 0  10419.0   COMED     32.0
# 1   9940.0   COMED     32.0
# 2   9604.0   COMED     35.6
# 3   9318.0   COMED     37.4
# 4   9224.0   COMED     37.4

# %%
droplist = df16[(df16['Temp(f)']> 60) & (df16['Temp(f)']<70)& (df16.MW > 16000) ].index

# %%
df16.drop(droplist,inplace = True)

# %%
df_2016 = df16.reset_index(drop=True)

# %%
df_2016d = df_2016[df_2016.Utility == 'DAYTON'].copy()

# %%
df_2016pos = df_2016d[df_2016d['Temp(f)'] >= 60].copy()
df_2016neg = df_2016d[df_2016d['Temp(f)'] < 60].copy()

# %%
X = df_2016pos["Temp(f)"].values.reshape(-1, 1)
y = df_2016pos["MW"].values.reshape(-1, 1)
print("Shape: ", X.shape, y.shape)
# Out:
# Shape:  (4183, 1) (4183, 1)

# %%
plt.scatter(X, y,color='g')
plt.title("Positive Dayton Data Plotted")
plt.show()

# %%
from sklearn.model_selection import train_test_split
model = LinearRegression()

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
model.fit(X_train, y_train)
training_score = model.score(X_train, y_train)
testing_score = model.score(X_test, y_test)

print(f"Training Score: {training_score}")
print(f"Testing Score: {testing_score}")
# Out:
# Training Score: 0.4864325376677196
# Testing Score: 0.47907732118112245

# %%
predictions = model.predict(X)
# Plot Residuals
plt.scatter(predictions, predictions - y)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.title("Residual Plot")
plt.show()

# %%
plt.scatter(model.predict(X_train), model.predict(X_train) - y_train, c="blue", label="Training Data")
plt.scatter(model.predict(X_test), model.predict(X_test) - y_test, c="orange", label="Testing Data")
plt.legend()
plt.hlines(y=0, xmin=y.min(), xmax=y.max())
plt.title("Residual Plot With Trained and Test Data")
# Out:
# Text(0.5, 1.0, 'Residual Plot With Trained and Test Data')

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
# Out:
# Weight coefficients:  [[36.10837839]]
# y-axis intercept:  [-603.72080973]

# %%
y_min_actual = y.min()
y_max_actual = y.max()
x_min = X.min()
x_max = X.max()
y_min_predicted = model.predict([[x_min]])
y_max_predicted = model.predict([[x_max]])
print(f"Actual Min Value: {y_min_actual}")
print(f"Predicted Min Value: {y_min_predicted}")
print(f"Actual Max Value: {y_max_actual}")
print(f"Predicted Max Value: {y_max_predicted}")
y_min =  -603.72080973+ 36.10837839 * x_min
y_max = -603.72080973+ 36.10837839 * x_max
# Out:
# Actual Min Value: 1199.0
# Predicted Min Value: [[1563.14297773]]
# Actual Max Value: 3327.0
# Predicted Max Value: [[3042.86432433]]

# %%
plt.scatter(X, y, c='blue')
plt.title("Plot With Model for Dayton Positive")
plt.plot([x_min, x_max], [y_min, y_max], c='red')

# %%
predictions = model.predict(X)
print(f"True output: {y[0]}")
print(f"Predicted output: {predictions[0]}")
print(f"Prediction Error: {predictions[0]-y[0]}")
# Out:
# True output: [1433.]
# Predicted output: [1721.65875888]
# Prediction Error: [288.65875888]

# %%
pd.DataFrame({"Predicted": [predictions], "Actual": [y], "Error": [predictions - y]})[["Predicted", "Actual", "Error"]]
# Out:
#                                            Predicted  \
# 0  [[1721.6587588771713], [1656.66367776703], [15...
#
#                                               Actual  \
# 0  [[1433.0], [1398.0], [1671.0], [1646.0], [1630...
#
#                                                Error
# 0  [[288.6587588771713], [258.6636777670301], [-7...
